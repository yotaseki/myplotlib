# %%
import numpy as np
import matplotlib.pyplot as plt
import myplotlib as myplt

# %%
a = np.zeros((3,20,20,3),dtype=np.float32)
b = np.ones((3,10,10,3),dtype=np.float32)
fig,ax = myplt.plot_images2((a,b,a,b,a,a,b,b,a))
plt.show()
# Out:
# 3 9
